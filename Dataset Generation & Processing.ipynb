# %% [markdown]
# # Data Generation

# %% [markdown]
# ## Imports & Variables

# %%
import random
import os
from PIL import Image
import json
from tqdm import tqdm
import time
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split

import utils_gen
import utils_helper

# %%
seed = 2022
random.seed(seed)

# %%
debug = False
save_gen = True

# %%
path_scenegraph = "./data/scenegraphs"
path_L2L3 = "./data/L2L3_captions.json"

# %% [markdown]
# ## Scenegraph Parsing & L1 Generation

# %%
data_L1 = []
n_success = 0
n_error = 0

files_sg = list(filter(lambda k: 'json' in k, os.listdir(path_scenegraph)))
files_sg.sort()
assert(len(files_sg) == 8822)

for file in tqdm(files_sg):
    filepath = os.path.join(path_scenegraph, file)
    with open(filepath) as f:
        read_sg = json.load(f)
#         read_sg = json.loads(f.read().decode("utf-8"))
        try:
            parsed_sg = utils_gen.parse_all_sg(read_sg)
            parsed_dt = utils_gen.parse_all_dt(read_sg)
            parsed_metadata = utils_gen.parse_all_sg(read_sg,src=False)
            parsed_caption, parsed_metadatadict = utils_gen.generate_caption(*parsed_metadata)
            data_L1.append((file.replace(".json",""), parsed_sg, parsed_dt, parsed_caption, parsed_metadata))
            if debug:
                print(f"Parsed Scenegraph: {parsed_sg}\n")
                print(f"Parsed Datatable: {parsed_dt}\n")
                print(f"Parsed L1 Metadata: {parsed_metadata}")
                display(Image.open(os.path.join("./data/images", file.replace(".json",".png"))))
                print(f"Parsed Caption: {parsed_caption}")
#                 print(parsed_metadatadict)
                break
            n_success += 1
        except Exception as e:
            n_error += 1
            print(e)
print(f"Successes: {n_success}")
print(f"Errors: {n_error}")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 8822/8822 [00:58<00:00, 151.53it/s]
# Successes: 8822
# Errors: 0

# %%
if save_gen:
    with open("./data/L1gen/L1gen.pkl", 'wb') as f:
        pickle.dump(data_L1, f)

# %% [markdown]
# ## Data Preprocessing

# %%
df_L1 = pd.DataFrame(data_L1, columns=["img_id", "scenegraph", "datatable", "caption_L1", "L1_properties"])
df_L1["img_id"] = pd.to_numeric(df_L1["img_id"])
df_L1.head()
# Out:
#    img_id                                         scenegraph  \
# 0       1  title National Football League average ticket ...
# 1      10  title Average ticket price Tampa Bay Lightning...
# 2     100  title Annual number of hospital beds in the Un...
# 3    1000  title Average monthly salary in public sector ...
# 4    1001  title Household penetration rates for dog-owne...
#
#                                            datatable  \
# 0  National Football League average ticket price ...
# 1  Average ticket price Tampa Bay Lightning (NHL)...
# 2  Annual number of hospital beds in the United K...
# 3  Average monthly salary in public sector in Swe...
# 4  Household penetration rates for dog-ownership ...
#
#                                           caption_L1  \
# 0  National Football League average ticket price ...
# 1  Here a bar plot is titled Average ticket price...
# 2  Annual number of hospital beds in the United K...
# 3  Average monthly salary in public sector in Swe...
# 4  Household penetration rates for dog-ownership ...
#
#                                        L1_properties
# 0  [line, National Football League average ticket...
# 1  [bar, Average ticket price Tampa Bay Lightning...
# 2  [bar, Annual number of hospital beds in the Un...
# 3  [area, Average monthly salary in public sector...
# 4  [area, Household penetration rates for dog-own...

# %%
with open(path_L2L3, 'rb') as f:
    df_L2L3 = pd.read_json(pickle.load(f), lines=True)
df_L2L3["caption_L2L3"] = df_L2L3["caption_L2L3"].map(utils_helper.cleanL2L3)
df_L2L3.head()
# Out:
#    img_id                                       caption_L2L3
# 0    7219  liverpool's broadcasting revenue has almost qu...
# 1    3451  people spent most of their money on shelter an...
# 2    2553  as time has gone on, there have been less peop...
# 3    5364  unemployment skyrocketed between ~2008-2012. t...
# 4    5879  population was already incredibly high. signif...

# %%
df_joint = df_L1.set_index("img_id").join(df_L2L3.set_index("img_id"), on="img_id", how="right")
df_joint = df_joint.sort_values(by="img_id", ascending=True)
df_joint = df_joint.reset_index()
df_joint.head()
# Out:
#    img_id                                         scenegraph  \
# 0       1  title National Football League average ticket ...
# 1       2  title Average viewers of Minecraft on Twitch w...
# 2       2  title Average viewers of Minecraft on Twitch w...
# 3       3  title Worldwide number of Michelin 's full-tim...
# 4       3  title Worldwide number of Michelin 's full-tim...
#
#                                            datatable  \
# 0  National Football League average ticket price ...
# 1  Average viewers of Minecraft on Twitch worldwi...
# 2  Average viewers of Minecraft on Twitch worldwi...
# 3  Worldwide number of Michelin 's full-time empl...
# 4  Worldwide number of Michelin 's full-time empl...
#
#                                           caption_L1  \
# 0  National Football League average ticket price ...
# 1  This is a area plot titled Average viewers of ...
# 2  This is a area plot titled Average viewers of ...
# 3  This is a area plot labeled Worldwide number o...
# 4  This is a area plot labeled Worldwide number o...
#
#                                        L1_properties  \
# 0  [line, National Football League average ticket...
# 1  [area, Average viewers of Minecraft on Twitch ...
# 2  [area, Average viewers of Minecraft on Twitch ...
# 3  [area, Worldwide number of Michelin 's full-ti...
# 4  [area, Worldwide number of Michelin 's full-ti...
#
#                                         caption_L2L3
# 0  The ticket price shown for 2006 is just over 6...
# 1  Viewers of Minecraft on twitch has gradually i...
# 2  Minecraft viewing on Twitch sharply increased ...
# 3  employees have remained pretty stable througho...
# 4  The worldwide number of full time employees is...

# %%
df_joint["img_id"] = df_joint["img_id"].map(str)
captionnumber = df_joint["img_id"] + "_" + df_joint.groupby("img_id").cumcount().add(1).astype(str).str.zfill(2)
df_joint["caption_id"] = captionnumber
# df_joint["img_filename"] = df_joint["img_id"]+".png"
df_joint.head()
# Out:
#   img_id                                         scenegraph  \
# 0      1  title National Football League average ticket ...
# 1      2  title Average viewers of Minecraft on Twitch w...
# 2      2  title Average viewers of Minecraft on Twitch w...
# 3      3  title Worldwide number of Michelin 's full-tim...
# 4      3  title Worldwide number of Michelin 's full-tim...
#
#                                            datatable  \
# 0  National Football League average ticket price ...
# 1  Average viewers of Minecraft on Twitch worldwi...
# 2  Average viewers of Minecraft on Twitch worldwi...
# 3  Worldwide number of Michelin 's full-time empl...
# 4  Worldwide number of Michelin 's full-time empl...
#
#                                           caption_L1  \
# 0  National Football League average ticket price ...
# 1  This is a area plot titled Average viewers of ...
# 2  This is a area plot titled Average viewers of ...
# 3  This is a area plot labeled Worldwide number o...
# 4  This is a area plot labeled Worldwide number o...
#
#                                        L1_properties  \
# 0  [line, National Football League average ticket...
# 1  [area, Average viewers of Minecraft on Twitch ...
# 2  [area, Average viewers of Minecraft on Twitch ...
# 3  [area, Worldwide number of Michelin 's full-ti...
# 4  [area, Worldwide number of Michelin 's full-ti...
#
#                                         caption_L2L3 caption_id
# 0  The ticket price shown for 2006 is just over 6...       1_01
# 1  Viewers of Minecraft on twitch has gradually i...       2_01
# 2  Minecraft viewing on Twitch sharply increased ...       2_02
# 3  employees have remained pretty stable througho...       3_01
# 4  The worldwide number of full time employees is...       3_02

# %% [markdown]
# ## Train/Test/Val Split

# %%
L2L3_split = {'train': [],
              'test': [],
              'val': []}

# %%
ids_L2L3 = list(df_joint["img_id"].unique())
assert(len(ids_L2L3) == 8822)
L2L3_split['train'], L2L3_rest = train_test_split(ids_L2L3, train_size=0.8, shuffle=True, random_state=seed)
L2L3_split['test'], L2L3_split['val'] = train_test_split(L2L3_rest, test_size=0.5, shuffle=True, random_state=seed)

# %%
with open('./data/splits.json', 'w') as f:
    json.dump(L2L3_split, f)

# %%
df_joint["split"] = df_joint["img_id"].map(lambda x: "train" if x in L2L3_split['train'] else ("test" if x in L2L3_split['test'] else "validation"))
df_joint = df_joint[["caption_id", "img_id", "split", "scenegraph", "datatable", "caption_L1", "caption_L2L3", "L1_properties"]]
df_joint.head()
# Out:
#   caption_id img_id       split  \
# 0       1_01      1       train
# 1       2_01      2       train
# 2       2_02      2       train
# 3       3_01      3  validation
# 4       3_02      3  validation
#
#                                           scenegraph  \
# 0  title National Football League average ticket ...
# 1  title Average viewers of Minecraft on Twitch w...
# 2  title Average viewers of Minecraft on Twitch w...
# 3  title Worldwide number of Michelin 's full-tim...
# 4  title Worldwide number of Michelin 's full-tim...
#
#                                            datatable  \
# 0  National Football League average ticket price ...
# 1  Average viewers of Minecraft on Twitch worldwi...
# 2  Average viewers of Minecraft on Twitch worldwi...
# 3  Worldwide number of Michelin 's full-time empl...
# 4  Worldwide number of Michelin 's full-time empl...
#
#                                           caption_L1  \
# 0  National Football League average ticket price ...
# 1  This is a area plot titled Average viewers of ...
# 2  This is a area plot titled Average viewers of ...
# 3  This is a area plot labeled Worldwide number o...
# 4  This is a area plot labeled Worldwide number o...
#
#                                         caption_L2L3  \
# 0  The ticket price shown for 2006 is just over 6...
# 1  Viewers of Minecraft on twitch has gradually i...
# 2  Minecraft viewing on Twitch sharply increased ...
# 3  employees have remained pretty stable througho...
# 4  The worldwide number of full time employees is...
#
#                                        L1_properties
# 0  [line, National Football League average ticket...
# 1  [area, Average viewers of Minecraft on Twitch ...
# 2  [area, Average viewers of Minecraft on Twitch ...
# 3  [area, Worldwide number of Michelin 's full-ti...
# 4  [area, Worldwide number of Michelin 's full-ti...

# %% [markdown]
# ## Export

# %%
df_train = df_joint[df_joint["split"] == "train"]
df_test = df_joint[df_joint["split"] == "test"]
df_val = df_joint[df_joint["split"] == "validation"]
assert(len(df_train)+len(df_test)+len(df_val) == 12441)

# %%
data_train = df_train.to_json(orient="records", lines=True)
data_test = df_test.to_json(orient="records", lines=True)
data_val = df_val.to_json(orient="records", lines=True)

with open("./data/data_train.json", "w") as f:
    f.write(data_train)
with open("./data/data_test.json", "w") as f:
    f.write(data_test)
with open("./data/data_validation.json", "w") as f:
    f.write(data_val)
